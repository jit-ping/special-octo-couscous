# %%
from functions import *

DMS = True #False if using normal lat long (ie. 1.3098, 103.7775)

sg_locations = [
    [(1, 21, 56.84, 'N'), (103, 50, 57.68, 'E')], # Add new lat longs in bracket() with , at end of bracket
    [(1, 21, 56.78, 'N'), (103, 50, 55.99, 'E')],
    [(1, 21, 51.99, 'N'), (103, 50, 55.60, 'E')],
    [(1, 21, 52.29, 'N'), (103, 50, 58.08, 'E')],
]

# Define the path to your file
geojson_file_path = "LTAMRTStationExitGEOJSON.geojson"

# Load the MRT data from the file
mrt_data_list = load_mrt_data_from_geojson(geojson_file_path)

# Run the function using data just loaded
converted_sg_locations = []
if DMS:
    # Use a list comprehension for a concise, faster conversion
    converted_sg_locations = [
        (
            dms_to_dd(a[0], a[1], a[2], a[3]),
            dms_to_dd(b[0], b[1], b[2], b[3])
        )
        for a, b in sg_locations
    ]
else:
    converted_sg_locations = sg_locations

print(converted_sg_locations)

mrt_info, my_singapore_map = get_interactive_map_and_mrt_geojson(converted_sg_locations, mrt_data_list)

# Print the string result
print("\n--- Nearest MRT ---")
print(mrt_info)

my_singapore_map
